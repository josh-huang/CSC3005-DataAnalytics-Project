# %% [markdown]
# __Step:__
#
# 1)Import linear model.LogisticRegession from sklearn
#
# 2)Import SVC from sklearn.svm
#
# 3)Set C range from 0.01,0.1,0.2,0.5,0.8,1,5,10,20,50
#
# 4)Repeat the same process of fitting with X_train and Y_train and predicting with X_train adn X_test
#
# 5)Calculate the accuracy score for testing and training prediction and plot verus various C

# %%
###########################################################
# Create the Training and Test set with split 70:30 
##########################################################

from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.svm import SVC
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd
import numpy as np

#load in the data

dataframeA = pd.read_csv('6. Dataset PCA File/MeterA_pca.csv')
#display(dataframeA.head())
dataframeA.head()

dataframeA = dataframeA.drop('Unnamed: 0', axis=1)
#extract features and target variables
Y = dataframeA["Class Attruibute"]
X = dataframeA[['PC1','PC2']] #dataframeA.drop(columns="Class Attruibute")


dataframeA = dataframeA[['PC1','PC2']]

#featuresVector
#dataframeA

X.shape
# Out:
# (83, 2)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=12)

# %% [markdown]
# Using features file

# %%
C = [0.01, 0.1, 0.2, 0.5, 0.8, 1, 5, 10, 20, 50]

LRtrainAcc = []
LRtestAcc = []
SVMtrainAcc = []
SVMtestAcc = []

for param in C:
    clf = linear_model.LogisticRegression(C=param)
    clf.fit(X_train, Y_train)
    Y_predTrain = clf.predict(X_train)
    Y_predTest = clf.predict(X_test)
    LRtrainAcc.append(accuracy_score(Y_train, Y_predTrain))
    LRtestAcc.append(accuracy_score(Y_test, Y_predTest))

    clf2 = SVC(C=param,kernel='linear')
    clf2.fit(X_train, Y_train)
    Y_predTrain = clf2.predict(X_train)
    Y_predTest = clf2.predict(X_test)
    SVMtrainAcc.append(accuracy_score(Y_train, Y_predTrain))
    SVMtestAcc.append(accuracy_score(Y_test, Y_predTest))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,6))
ax1.plot(C, LRtrainAcc, 'ro-', C, LRtestAcc,'bv--')
ax1.legend(['Training Accuracy For Logistic','Test Accuracy'])
ax1.set_xlabel('C')
ax1.set_xscale('log')
ax1.set_ylabel('Accuracy')

ax2.plot(C, SVMtrainAcc, 'ro-', C, SVMtestAcc,'bv--')
ax2.legend(['Training Accuracy For SVM','Test Accuracy'])
ax2.set_xlabel('C')
ax2.set_xscale('log')
ax2.set_ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# Observation:Note that linear classifiers perform poorly on the data since the true decision boundaries between
# classes are nonlinear for the given 2-dimensional dataset. Can you visualize?

# %%
dataframeB = pd.read_csv('6. Dataset PCA File/MeterB_pca.csv') #6. Dataset PCA File/MeterA_pca.csv
#display(dataframeA.head()) 
dataframeB.head()

dataframeB = dataframeB.drop('Unnamed: 0', axis=1)
#extract features and target variables
Y_B = dataframeB["Class Attruibute"]
X_B =  dataframeB[['PC1','PC2']] #dataframeB.drop(columns="Class Attruibute")


dataframeB = dataframeB[['PC1','PC2']]

#featuresVector
#dataframeA

X_B.shape
# Out:
# (68, 2)

# %%
X_train_B, X_test_B, Y_train_B, Y_test_B = train_test_split(X_B, Y_B, test_size=0.3, random_state=12)

# %%
C = [0.01, 0.1, 0.2, 0.5, 0.8, 1, 5, 10, 20, 50]

LRtrainAcc_B = []
LRtestAcc_B = []
SVMtrainAcc_B = []
SVMtestAcc_B = []

for param in C:
    clf3 = linear_model.LogisticRegression(C=param)
    clf3.fit(X_train_B, Y_train_B)
    Y_predTrain_B = clf3.predict(X_train_B)
    Y_predTest_B = clf3.predict(X_test_B)
    LRtrainAcc_B.append(accuracy_score(Y_train_B, Y_predTrain_B))
    LRtestAcc_B.append(accuracy_score(Y_test_B, Y_predTest_B))

    clf4 = SVC(C=param,kernel='linear')
    clf4.fit(X_train_B, Y_train_B)
    Y_predTrain_B = clf4.predict(X_train_B)
    Y_predTest_B = clf4.predict(X_test_B)
    SVMtrainAcc_B.append(accuracy_score(Y_train_B, Y_predTrain_B))
    SVMtestAcc_B.append(accuracy_score(Y_test_B, Y_predTest_B))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,6))
ax1.plot(C, LRtrainAcc_B, 'ro-', C, LRtestAcc_B,'bv--')
ax1.legend(['Training Accuracy For Logistic','Test Accuracy'])
ax1.set_xlabel('C')
ax1.set_xscale('log')
ax1.set_ylabel('Accuracy')

ax2.plot(C, SVMtrainAcc_B, 'ro-', C, SVMtestAcc_B,'bv--')
ax2.legend(['Training Accuracy For SVM','Test Accuracy'])
ax2.set_xlabel('C')
ax2.set_xscale('log')
ax2.set_ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
from sklearn.preprocessing import StandardScaler


scaler = StandardScaler()

dataframeC = pd.read_csv('6. Dataset PCA File/MeterC_pca.csv') #6. Dataset PCA File/MeterA_pca.csv
#display(dataframeA.head()) 
dataframeC.head()

dataframeC = dataframeC.drop('Unnamed: 0', axis=1)
#extract features and target variables
Y_C = dataframeC["Class Attruibute"]
X_C =  dataframeC[['PC1','PC2']] #dataframeC.drop(columns="Class Attruibute")


#dataframeC = dataframeC[['PC1','PC2']]

#scaler.fit_transform(dataframeC)

#featuresVector
#dataframeA

X_C.shape
# Out:
# (135, 2)

# %%
X_train_C, X_test_C, Y_train_C, Y_test_C = train_test_split(X_C, Y_C, test_size=0.3, random_state=12)

# %%
C = [0.01, 0.1, 0.2, 0.5, 0.8, 1, 5, 10, 20, 50]

LRtrainAcc_C = []
LRtestAcc_C = []
SVMtrainAcc_C = []
SVMtestAcc_C = []

for param in C:
    clf5 = linear_model.LogisticRegression(C=param)
    clf5.fit(X_train_C, Y_train_C)
    Y_predTrain_C = clf5.predict(X_train_C)
    Y_predTest_C = clf5.predict(X_test_C)
    LRtrainAcc_C.append(accuracy_score(Y_train_C, Y_predTrain_C))
    LRtestAcc_C.append(accuracy_score(Y_test_C, Y_predTest_C))

    clf6 = SVC(C=param,kernel='linear')
    clf6.fit(X_train_C, Y_train_C)
    Y_predTrain_C = clf6.predict(X_train_C)
    Y_predTest_C = clf6.predict(X_test_C)
    SVMtrainAcc_C.append(accuracy_score(Y_train_C, Y_predTrain_C))
    SVMtestAcc_C.append(accuracy_score(Y_test_C, Y_predTest_C))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,6))
ax1.plot(C, LRtrainAcc_C, 'ro-', C, LRtestAcc_C,'bv--')
ax1.legend(['Training Accuracy For Logistic','Test Accuracy'])
ax1.set_xlabel('C')
ax1.set_xscale('log')
ax1.set_ylabel('Accuracy')

ax2.plot(C, SVMtrainAcc_C, 'ro-', C, SVMtestAcc_C,'bv--')
ax2.legend(['Training Accuracy For SVM','Test Accuracy'])
ax2.set_xlabel('C')
ax2.set_xscale('log')
ax2.set_ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')
