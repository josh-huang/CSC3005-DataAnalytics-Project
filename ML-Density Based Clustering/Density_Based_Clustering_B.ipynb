# %%
import pandas as pd

dataA = pd.read_csv('../6. Dataset PCA/MeterB_pca.csv')
dataA_feature = dataA[['PC1','PC2']]
print(dataA_feature)
_ = dataA_feature.plot.scatter(x='PC1',y='PC2')
# Out:
#          PC1       PC2
# 0  -0.517006 -2.287902
# 1  -0.568945 -2.238254
# 2  -0.546921 -2.257404
# 3  -0.555591 -2.235918
# 4  -0.530154 -2.280878
# ..       ...       ...
# 63 -0.612061  1.350095
# 64 -0.583182  1.276827
# 65 -0.685925  1.286320
# 66 -0.756724  1.338792
# 67 -0.413888  1.325592
#
# [68 rows x 2 columns]

# %%
from sklearn.cluster import DBSCAN

# Parameters:
# eps: The maximum distance between two samples for one to be considered as in the neighborhood of the other
# min_samples: The number of samples (or total weight) in a neighborhood for a point to be considered as a core point. 
#              This includes the point itself

db = DBSCAN(eps=1, min_samples=2).fit(dataA_feature)
labels = pd.DataFrame(db.labels_,columns=['Cluster ID'])
result = pd.concat((dataA_feature,labels), axis=1)
print(result)
_ = result.plot.scatter(x='PC1',y='PC2',c='Cluster ID', colormap='jet')
# Out:
#          PC1       PC2  Cluster ID
# 0  -0.517006 -2.287902           0
# 1  -0.568945 -2.238254           0
# 2  -0.546921 -2.257404           0
# 3  -0.555591 -2.235918           0
# 4  -0.530154 -2.280878           0
# ..       ...       ...         ...
# 63 -0.612061  1.350095           1
# 64 -0.583182  1.276827           1
# 65 -0.685925  1.286320           1
# 66 -0.756724  1.338792           1
# 67 -0.413888  1.325592           1
#
# [68 rows x 3 columns]
