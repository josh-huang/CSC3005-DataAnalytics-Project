# %%
import pandas as pd

dataA = pd.read_csv('../5. Dataset PCA/MeterB_pca_all.csv')
dataA_feature = dataA[['PC1','PC2']]
print(dataA_feature)
_ = dataA_feature.plot.scatter(x='PC1',y='PC2')
# Out:
#          PC1       PC2
# 0  -1.078884  2.306985
# 1  -1.115494  2.243641
# 2  -1.119305  2.192690
# 3  -1.058113  2.148865
# 4  -1.092378  2.204525
# ..       ...       ...
# 71  4.735872 -3.386516
# 72  4.433571 -3.215012
# 73  5.140769 -3.448732
# 74  4.479070 -3.287830
# 75  4.312446 -3.193370
#
# [76 rows x 2 columns]

# %%
from sklearn.cluster import DBSCAN

# Parameters:
# eps: The maximum distance between two samples for one to be considered as in the neighborhood of the other
# min_samples: The number of samples (or total weight) in a neighborhood for a point to be considered as a core point. 
#              This includes the point itself

db = DBSCAN(eps=1, min_samples=2).fit(dataA_feature)
labels = pd.DataFrame(db.labels_,columns=['Cluster ID'])
result = pd.concat((dataA_feature,labels), axis=1)
print(result)
_ = result.plot.scatter(x='PC1',y='PC2',c='Cluster ID', colormap='jet')
# Out:
#          PC1       PC2  Cluster ID
# 0  -1.078884  2.306985           0
# 1  -1.115494  2.243641           0
# 2  -1.119305  2.192690           0
# 3  -1.058113  2.148865           0
# 4  -1.092378  2.204525           0
# ..       ...       ...         ...
# 71  4.735872 -3.386516           5
# 72  4.433571 -3.215012           5
# 73  5.140769 -3.448732           5
# 74  4.479070 -3.287830           5
# 75  4.312446 -3.193370           5
#
# [76 rows x 3 columns]
