# %%
import pandas as pd
from sklearn.metrics import plot_confusion_matrix

# %%
# Load and check data

dataframeA = pd.read_csv('../5. Dataset PCA/MeterA_pca_3.csv')
#display(dataframeA.head())
dataframeA.head()

dataframeA = dataframeA.drop('Unnamed: 0', axis=1)

PCA_A_DF = dataframeA

# yLbl is Class Attruibute labels

yLbl = dataframeA[['Class Attruibute']]

#featuresVector

# %%
###########################################################
# Create the Training and Test set with split 70:30 
##########################################################

from sklearn.model_selection import train_test_split
PCA_A_train, PCA_A_test, yLbl_train, yLbl_test = train_test_split(PCA_A_DF, yLbl, test_size=0.3, random_state=12)
#X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=12)
from sklearn import tree
from sklearn.metrics import accuracy_score

# %%
print("Training Set")
PCA_A_train
# Out:
# Training Set
#          PC1       PC2       PC3  Class Attruibute
# 61 -2.724320 -0.754879  0.957070                 2
# 26 -2.877574  0.012485 -0.331946                 1
# 10 -1.557377 -0.062903 -0.774039                 1
# 79  0.965500 -3.437027  0.754479                 2
# 78  0.724850 -3.055172  0.638940                 2
# 77  1.413328 -3.407719  0.784772                 2
# 41  1.626168 -0.239633 -1.456491                 2
# 54 -0.514188  1.652241  0.245752                 2
# 39  2.061802 -0.635565 -0.779664                 2
# 36  1.473248 -0.193995 -1.204482                 2
# 38  2.074590 -0.348814 -1.330807                 2
# 11 -1.837657 -0.773897 -0.878323                 1
# 1   1.016687  3.352036  0.894510                 1
# 40  1.432439  0.171493 -1.022424                 2
# 73  3.959184 -1.464863 -0.254494                 2
# 4  -0.280666  1.219715 -1.401910                 1
# 63 -2.831047 -0.682861  0.764677                 2
# 51 -0.348866  1.109864  0.905282                 2
# 15 -2.154159 -0.899574 -0.131935                 1
# 24 -1.140094  0.958959  0.147142                 1
# 25 -1.684337  0.596279 -0.593443                 1
# 81  0.471616 -2.909196  0.075192                 2
# 46 -1.241596 -1.592821 -0.393068                 2
# 60 -3.243068 -0.892968  0.890595                 2
# 82  0.042004 -2.488026  0.028047                 2
# 65  4.696736  1.629314  2.936891                 2
# 53 -0.353138  1.182008  0.684088                 2
# 9  -0.675132  0.590552 -0.598195                 1
# 45 -1.058268 -1.732053 -0.564018                 2
# 80  0.177245 -3.400804  0.782970                 2
# 20  1.403228  2.265514 -0.211040                 1
# 16 -3.726524 -1.063301 -0.708046                 1
# 50  0.446671  1.575793 -0.286782                 2
# 74  2.963067 -2.249923 -0.321901                 2
# 18  1.844272  1.229209  0.714531                 1
# 32 -5.010969 -0.034459  0.264574                 1
# 55 -0.510452  1.801782 -0.457978                 2
# 30 -2.758558  0.132151  0.246135                 1
# 33  1.814708  3.798642 -0.108594                 2
# 66  6.036821 -0.932438  0.672652                 2
# 62 -2.884711 -0.767628  1.273864                 2
# 35  2.524633  0.732763 -0.293854                 2
# 70  2.674013 -1.418282  0.011342                 2
# 0  -0.526258  5.566278  0.389358                 1
# 34  2.218775  1.992243  0.091133                 2
# 13 -2.306482 -0.684039 -0.104873                 1
# 5  -0.287587  1.451361 -1.449791                 1
# 52  0.097439  1.177387  0.089981                 2
# 49 -0.150677  2.039465  0.828369                 2
# 22  0.290366  1.371007  0.335618                 1
# 48  0.256859  4.086299 -0.500018                 2
# 76  1.238582 -3.002790  0.000306                 2
# 67  3.903145 -0.481472  1.045117                 2
# 3  -0.173012  1.540431 -0.850760                 1
# 2   1.058280  1.844760  0.667599                 1
# 6   0.265328  1.536294 -1.052959                 1
# 27 -2.647580 -0.192080  0.583833                 1
# 75  2.385757 -2.753788  0.072044                 2

# %%
print("Testing Set -30%")
PCA_A_test
# Out:
# Testing Set -30%
#          PC1       PC2       PC3  Class Attruibute
# 17  2.386057  2.377597  1.130918                 1
# 19  1.665820  1.015200  0.729203                 1
# 43 -1.416963 -1.602036 -0.642507                 2
# 47 -1.230944 -1.480375 -0.282906                 2
# 12 -2.016995 -0.345941 -0.138615                 1
# 8   0.640821  1.266542 -1.097377                 1
# 44 -1.262361 -1.631269 -0.614526                 2
# 23 -0.433696  1.914981  0.059627                 1
# 14 -2.430617 -0.801707 -0.191984                 1
# 7  -0.026527  1.545473 -0.834414                 1
# 64 -3.676232 -0.989616  1.137127                 2
# 31 -3.090315 -0.091040 -0.038749                 1
# 59 -2.534861 -0.712400  0.258149                 2
# 28 -2.850499  0.016629  0.244525                 1
# 56 -0.931637  0.594491  0.825780                 2
# 68  3.335285 -1.822627  0.253672                 2
# 21  0.570327  2.129340  0.178790                 1
# 71  3.676615 -1.468566 -0.317489                 2
# 72  3.164433 -1.281849 -0.273131                 2
# 37  1.724345  0.449979 -1.675793                 2
# 57 -1.529964  0.293941  0.197055                 2
# 69  3.233759 -1.763632 -0.400189                 2
# 42  0.044040 -1.521774 -0.338723                 2
# 58 -2.212605 -0.168202  0.411214                 2
# 29 -2.850331  0.013504  0.705315                 1

# %% [markdown]
# **Apply KNN algo and plot results and calculate**

# %%
# Use a nearest neighbor classifier to evaluate the methods
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
# %matplotlib inline

# different num of neighbors to compare performance
numNeighbors = [1, 5, 10, 15, 20, 25, 30,35, 45, 50,55]
trainAcc = []
testAcc = []

for k in numNeighbors:
    clf1 = KNeighborsClassifier(n_neighbors=k, metric='minkowski', p=2)
    clf1.fit(PCA_A_train,yLbl_train.values.ravel())
    PCA_A_predTrain = clf1.predict(PCA_A_train)
    PCA_A_predTest = clf1.predict(PCA_A_test)
    trainAcc.append(accuracy_score(yLbl_train, PCA_A_predTrain))
    testAcc.append(accuracy_score(yLbl_test, PCA_A_predTest))

plt.plot(numNeighbors, trainAcc, 'ro-', numNeighbors, testAcc,'bv--')
plt.legend(['Training Accuracy','Test Accuracy'])
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy')

plot_confusion_matrix(clf1, PCA_A_test, yLbl_test)
plt.show()

# calculate RMSE
from sklearn.metrics import mean_squared_error
import math
 
MSE = mean_squared_error(yLbl_test, PCA_A_predTest)
 
RMSE = math.sqrt(MSE)
print("Root Mean Square Error:\n")
print(RMSE)
# Out:
# Root Mean Square Error:
#
# 0.6633249580710799

# %% [markdown]
# **Meter B**

# %%
# Load and check data

dataframeB = pd.read_csv('../5. Dataset PCA/MeterB_pca_4.csv')
#display(dataframeA.head())
dataframeB.head()

dataframeB = dataframeB.drop('Unnamed: 0', axis=1)

PCA_B_DF = dataframeB

# yLbl is Class Attruibute labels

yLbl_B = dataframeB[['Class Attruibute']]

#featuresVector
PCA_B_DF
# Out:
#          PC1       PC2       PC3       PC4  Class Attruibute
# 0  -1.078884  2.306985 -1.566801 -0.147993                 1
# 1  -1.115494  2.243641 -1.536997 -0.167253                 1
# 2  -1.119305  2.192690 -1.414351  0.307790                 1
# 3  -1.058113  2.148865 -1.273970  0.360431                 1
# 4  -1.092378  2.204525 -1.444502  0.384623                 1
# ..       ...       ...       ...       ...               ...
# 71  4.735872 -3.386516 -1.556820  0.624459                 3
# 72  4.433571 -3.215012 -1.466567  0.598843                 3
# 73  5.140769 -3.448732 -1.407565  0.643601                 3
# 74  4.479070 -3.287830 -1.630329  0.460822                 3
# 75  4.312446 -3.193370 -1.534603  0.513509                 3
#
# [76 rows x 5 columns]

# %%
###########################################################
# Create the Training and Test set with split 70:30 
##########################################################

from sklearn.model_selection import train_test_split
PCA_B_train, PCA_B_test, yLbl_B_train, yLbl_B_test = train_test_split(PCA_B_DF, yLbl_B, test_size=0.3, random_state=12)
#X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=12)
from sklearn import tree
from sklearn.metrics import accuracy_score

# %%
print("Training Set For B")
PCA_B_train
# Out:
# Training Set For B
#          PC1       PC2       PC3       PC4  Class Attruibute
# 19  1.901056  3.368554  1.242266 -1.269432                 2
# 21  5.491881  6.150927  4.128664 -2.095865                 2
# 28 -0.126774  2.855082 -1.913610 -1.446071                 2
# 65  4.409768 -1.816004 -0.342475 -1.092744                 3
# 55 -1.379699 -1.570503  0.470008  0.281978                 3
# 61 -1.418728 -1.688730  0.553037  0.774757                 3
# 1  -1.115494  2.243641 -1.536997 -0.167253                 1
# 38 -2.025697 -1.207346  1.009732  0.029185                 3
# 58 -1.428717 -1.608062  0.536837  0.802100                 3
# 4  -1.092378  2.204525 -1.444502  0.384623                 1
# 50 -2.231066 -1.410385  1.048849 -0.208385                 3
# 15 -1.093625  1.859133 -0.909777  1.468441                 1
# 24  1.229013  2.023949  2.277690  2.626936                 2
# 66  5.083247 -2.307073 -0.563488 -0.769483                 3
# 74  4.479070 -3.287830 -1.630329  0.460822                 3
# 46 -2.239803 -1.413598  1.041675 -1.583637                 3
# 47 -2.186180 -1.287486  0.958601 -1.433048                 3
# 9  -1.037581  2.024042 -1.007964  1.107553                 1
# 73  5.140769 -3.448732 -1.407565  0.643601                 3
# 20  2.792485  4.008718  1.609350 -1.190420                 2
# 16 -1.091306  1.855726 -0.905087  1.531327                 1
# 68  5.030043 -2.754945 -0.937912 -0.290092                 3
# 57 -1.475506 -1.656792  0.522315  0.713962                 3
# 32 -2.124277 -1.467940  1.034146  0.306970                 3
# 30  1.405777  4.336619 -0.428131 -2.551517                 2
# 33 -2.195967 -1.642136  1.175526  0.193830                 3
# 51 -2.152947 -1.251274  0.982087 -0.222508                 3
# 36 -2.161500 -1.373881  0.941969 -0.005674                 3
# 35 -2.111124 -1.270090  0.923448 -0.051801                 3
# 63 -1.279649 -1.616336  0.591346  1.036056                 3
# 18 -1.123385  1.739085 -0.791179  1.921467                 1
# 64  4.494853 -1.622638  0.135966 -0.832914                 3
# 12 -1.123288  1.872176 -0.909855  1.464713                 1
# 40 -2.170347 -1.229907  0.936533 -1.197638                 3
# 53  0.555663 -2.704648  1.503622 -0.900906                 3
# 0  -1.078884  2.306985 -1.566801 -0.147993                 1
# 10 -1.018216  1.906365 -0.887050  1.359077                 1
# 54 -0.542859 -3.392087  0.862072 -0.737612                 3
# 11 -1.154181  1.890373 -0.996568  1.367388                 1
# 34 -2.138643 -1.464614  1.082065 -0.072384                 3
# 25  0.015150  2.525523 -2.157014 -1.254221                 2
# 13 -1.049078  1.881442 -0.867764  1.473311                 1
# 5  -1.041429  2.192730 -1.318675  0.423057                 1
# 52 -0.845114 -4.246885  1.347602 -0.897943                 3
# 49 -2.014113 -1.169503  1.054441 -0.366641                 3
# 22  7.677308  5.367620  6.589277  3.757157                 2
# 48 -2.098522 -1.079541  0.838765 -0.834730                 3
# 67  4.149456 -1.929107 -0.671732 -0.704455                 3
# 3  -1.058113  2.148865 -1.273970  0.360431                 1
# 2  -1.119305  2.192690 -1.414351  0.307790                 1
# 6  -1.114643  2.148410 -1.306423  0.241218                 1
# 27 -0.184158  2.781275 -2.048718 -1.280864                 2
# 75  4.312446 -3.193370 -1.534603  0.513509                 3

# %%
print("Testing Set For B")
PCA_B_test
# Out:
# Testing Set For B
#          PC1       PC2       PC3       PC4  Class Attruibute
# 23  0.251945  1.747706 -0.605822  1.234623                 2
# 17 -1.124987  1.830307 -0.887064  1.683602                 1
# 26 -0.070722  2.502103 -2.232260 -1.216566                 2
# 7  -1.087676  2.135053 -1.285580  0.294072                 1
# 8  -1.098805  2.055208 -1.162398  0.598390                 1
# 56 -1.413485 -1.582973  0.507951  0.681181                 3
# 14 -1.086538  1.846689 -0.918031  1.450478                 1
# 29  0.248160  2.942995 -1.711460 -1.968253                 2
# 37 -2.050359 -1.247402  0.936125  0.062323                 3
# 44 -2.134591 -1.175262  0.901158 -1.005532                 3
# 43 -2.247866 -1.313261  0.901620 -1.213447                 3
# 72  4.433571 -3.215012 -1.466567  0.598843                 3
# 71  4.735872 -3.386516 -1.556820  0.624459                 3
# 60 -1.338935 -1.605302  0.571498  0.832168                 3
# 45 -2.148291 -1.167214  0.893950 -1.151006                 3
# 41 -2.191266 -1.326034  1.018660 -1.108515                 3
# 59 -1.380744 -1.626260  0.619856  0.753394                 3
# 31  1.907840  4.828200  1.186122 -3.202546                 2
# 62 -1.446942 -1.772934  0.693960  0.693022                 3
# 42 -2.130556 -1.120881  0.828463 -1.045022                 3
# 69  3.693980 -2.510292 -1.356839  0.067584                 3
# 70  4.550183 -3.202266 -1.527027  0.336703                 3
# 39 -2.195474 -1.409668  1.025156  0.055021                 3

# %%
# next, we'll apply a knn algorithm to see (in terms of proximity) how close are the values in our pca to observations that have a stroke

# Use a nearest neighbor classifier to evaluate the methods

numNeighbors_B = [1, 5, 10, 15, 20, 25, 30,35, 45]
trainAccB = []
testAccB = []

# loop through the array and apply different num of neighbors
for k in numNeighbors_B:
    clf1 = KNeighborsClassifier(n_neighbors=k, metric='minkowski', p=2)
    clf1.fit(PCA_B_train,yLbl_B_train.values.ravel())
    PCA_B_predTrain = clf1.predict(PCA_B_train)
    PCA_B_predTest = clf1.predict(PCA_B_test)
    trainAccB.append(accuracy_score(yLbl_B_train, PCA_B_predTrain))
    testAccB.append(accuracy_score(yLbl_B_test, PCA_B_predTest))

plt.plot(numNeighbors_B, trainAccB, 'ro-', numNeighbors_B, testAccB,'bv--')
plt.legend(['Training Accuracy','Test Accuracy'])
plt.xlabel('Number of neighbors For PCA B')
plt.ylabel('Accuracy')

# plot confusion matrix
plot_confusion_matrix(clf1, PCA_B_test, yLbl_B_test)
plt.show()

# calculate RMSE
MSE = mean_squared_error(yLbl_B_test, PCA_B_predTest)
 
RMSE = math.sqrt(MSE)
print("Root Mean Square Error:\n")
print(RMSE)
# Out:
# Root Mean Square Error:
#
# 0.9325048082403138

# %%
# Load and check data

dataframeC = pd.read_csv('../5. Dataset PCA/MeterC_pca_8.csv')
#display(dataframeA.head())
dataframeC.head()

dataframeC = dataframeC.drop('Unnamed: 0', axis=1)

PCA_C_DF = dataframeC

# yLbl is Class Attruibute labels

yLbl_C = dataframeC[['Class Attruibute']]

#featuresVector
PCA_C_DF
# Out:
#           PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0    0.102593 -0.829562 -1.676971 -1.007938 -0.098190 -0.684320  0.804384
# 1   -0.040133 -0.770644 -1.239189 -0.704165 -0.048586 -0.617471  0.646651
# 2   -0.037532 -0.790725 -1.256575 -0.667411 -0.047701 -0.623065  0.652478
# 3   -0.046404 -0.793948 -1.238038 -0.668665 -0.054041 -0.628834  0.630414
# 4   -0.015392 -0.764792 -1.264105 -0.661812 -0.042025 -0.594175  0.657839
# ..        ...       ...       ...       ...       ...       ...       ...
# 174  4.901751 -0.866004  0.073887 -1.446518  2.645641  0.200072 -2.417032
# 175  5.759641 -1.308838  0.270686 -2.091214  3.637937  0.203921 -3.332701
# 176  3.746537  1.145021 -0.419253 -2.679277  2.933623 -0.808249 -3.104220
# 177  5.433919 -0.839261 -0.038141 -2.141826  3.230629 -0.010055 -2.956233
# 178  4.837667  0.870165 -1.024920 -2.071849  2.911283  0.257043 -2.297224
#
#           PC8  Class Attruibute
# 0    0.209089                 1
# 1    0.143172                 1
# 2    0.159872                 1
# 3    0.163785                 1
# 4    0.133782                 1
# ..        ...               ...
# 174  2.240824                 4
# 175  1.105017                 4
# 176  0.600130                 4
# 177  1.272151                 4
# 178  2.100049                 4
#
# [179 rows x 9 columns]

# %%
###########################################################
# Create the Training and Test set with split 70:30 
##########################################################

from sklearn.model_selection import train_test_split
PCA_C_train, PCA_C_test, yLbl_C_train, yLbl_C_test = train_test_split(PCA_C_DF, yLbl_C, test_size=0.3, random_state=20)
#X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=12)
from sklearn import tree
from sklearn.metrics import accuracy_score

# %%
print("Training Set For C")
PCA_C_train
# Out:
# Training Set For C
#           PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 132 -0.201062 -0.755537 -1.124028 -0.806923 -0.033254 -0.714563  0.485208
# 147 -1.247364 -0.080741  1.871797  1.428408  0.353206  0.254675 -0.373909
# 146 -0.958939 -0.279865  1.071664  0.905865  0.233829 -0.001213 -0.143044
# 130 -0.020859 -0.800212 -1.584456 -1.100877 -0.085469 -0.798366  0.634516
# 37  -0.693986 -0.430378  1.433107  0.801220  0.236277 -0.278058 -0.404810
# ..        ...       ...       ...       ...       ...       ...       ...
# 148 -1.244619 -0.082556  1.869883  1.441895  0.341984  0.259801 -0.368846
# 137 -0.376903 -0.652064 -0.795551 -0.414663  0.081491 -0.545482  0.355658
# 156 -0.119618 -0.072316  0.700372 -0.756739  1.442045  0.631369 -1.387481
# 15  -0.854768 -0.359054  1.041254  1.002943  0.168187  0.014144 -0.011949
# 99   0.045416 -0.886440 -1.226006 -0.384945 -0.271332 -0.593098  0.875268
#
#           PC8  Class Attruibute
# 132  0.125307                 4
# 147 -0.816440                 4
# 146 -0.549058                 4
# 130  0.202072                 4
# 37  -0.371090                 1
# ..        ...               ...
# 148 -0.817878                 4
# 137 -0.064029                 4
# 156 -0.678133                 4
# 15  -0.467526                 1
# 99   0.184152                 3
#
# [125 rows x 9 columns]

# %%
print("Testing Set For C")
PCA_C_test
# Out:
# Testing Set For C
#            PC1        PC2        PC3        PC4       PC5        PC6  \
# 112   0.069411  -0.890214  -1.607841  -0.745502 -0.116039  -0.781817
# 100   0.055746  -0.860874  -1.225714  -0.405181 -0.253470  -0.579005
# 46    0.381836  -0.778731  -0.855525  -1.058821 -0.114574  -0.832699
# 113  -0.077335  -0.857129  -1.207900  -0.423059 -0.112408  -0.689549
# 92   -0.820085  -0.103229   1.757372   1.579450  0.223069   0.407327
# 72   -3.816394   2.601285   1.310960   3.157520  0.878371   2.692331
# 107  -0.857824  -0.359625   0.940856   1.080339  0.089068   0.102895
# 108  -0.850215  -0.352703   0.939168   1.082987  0.078895   0.120633
# 126  -0.884700  -0.374131   0.992307   1.274893  0.138269   0.005455
# 102  -0.227842  -0.695265  -0.527183   0.296223 -0.155036  -0.298138
# 47    0.438459  -0.774575  -0.831862  -1.038683 -0.142357  -0.823455
# 166   0.053543  -0.906417  -2.455138  -1.309565 -3.979261   2.639011
# 121  -0.657070  -0.562426   0.461920   0.772167  0.042038  -0.252500
# 62   -1.915360  14.229014  -4.641348  -2.284301 -1.340111   1.209278
# 13   -0.850936  -0.350686   1.065809   0.951506  0.150647   0.010589
# 175   5.759641  -1.308838   0.270686  -2.091214  3.637937   0.203921
# 88   -0.628236  -0.297033   0.966277   0.996283  0.127123   0.143538
# 28   -0.729617  -0.494630   0.455276   0.519494  0.085393  -0.201467
# 51    0.350785  -0.798437  -0.817459  -0.983109 -0.106996  -0.915939
# 176   3.746537   1.145021  -0.419253  -2.679277  2.933623  -0.808249
# 170   0.500287  -1.195725  -3.183437  -1.864870 -4.043212   2.405027
# 44    0.091883  -0.642852  -0.166662  -0.353776  0.032644  -0.569871
# 125  -0.892728  -0.370983   0.976595   1.298936  0.165052   0.008284
# 34   -0.846091  -0.343943   1.047779   0.944485  0.142747  -0.013086
# 133  -0.216947  -0.706004  -1.235385  -0.735186  0.026172  -0.653376
# 77    0.157656  -0.725019  -1.322809  -0.612376 -0.060351  -0.498557
# 45    0.219508  -0.693423  -0.577055  -0.669105 -0.017790  -0.652365
# 134  -0.207414  -0.723935  -1.242900  -0.723263  0.010371  -0.650867
# 80    0.160186  -0.723753  -1.322590  -0.628783 -0.065577  -0.486637
# 104  -0.857079  -0.344571   0.963466   1.021027  0.040813   0.119337
# 68   -1.451804  -0.054951   2.919548   2.303165  0.270129   0.339277
# 154  -0.295921  -0.047303   1.210279  -0.148512  1.619984   1.022087
# 153   0.314172  -0.227816   0.883193  -0.315574  1.271689   0.620942
# 163   0.380138  -0.915053  -2.266307  -0.593374 -3.534187   3.528497
# 12   -0.880037  -0.358476   1.093507   0.950592  0.167267  -0.014670
# 55   -2.875457   1.413205   2.494935   0.788760 -0.335774   0.753457
# 1    -0.040133  -0.770644  -1.239189  -0.704165 -0.048586  -0.617471
# 67    5.279592   1.808800  12.406306 -10.177864 -4.692137  -1.685139
# 138  -0.503782  -0.588093  -0.394510  -0.134813  0.096339  -0.444950
# 64   11.485525   3.572197  -3.750477  11.519996 -3.032312  -1.149847
# 20   -0.136390  -0.770518  -1.210568  -0.702997 -0.070537  -0.653398
# 21   -0.115493  -0.790796  -1.231616  -0.667492 -0.051330  -0.656646
# 59   -2.869736   7.442361  -1.248874  -1.893124 -0.919625   0.711104
# 164   0.556355  -1.246951  -2.417192  -1.168444 -4.051949   2.988728
# 128  -1.111105  -0.170838   1.768959   1.832399  0.258202   0.266403
# 159  -0.137530  -0.092686   0.687077  -0.642436  1.440977   0.815141
# 29   -0.842107  -0.350231   1.030295   0.944302  0.150228  -0.016198
# 90   -0.636408  -0.298744   0.963190   0.993722  0.159947   0.125503
# 171  11.808690  -1.190361   1.084000  -2.947519  5.690306  10.530679
# 63   -2.108956  10.078933  -2.153478  -2.731478  0.165031   1.042036
# 35   -1.134509  -0.148095   1.877890   1.503870  0.245608   0.253058
# 97    0.062819  -0.892977  -1.239208  -0.380797 -0.272160  -0.607092
# 103  -0.528378  -0.549934   0.331432   0.925868 -0.070122  -0.076863
# 117  -0.082278  -0.843677  -1.203910  -0.450347 -0.091896  -0.682103
#
#           PC7       PC8  Class Attruibute
# 112  0.698425  0.275965                 3
# 100  0.858434  0.184720                 3
# 46   0.557268  0.318098                 1
# 113  0.571201  0.206797                 3
# 92  -0.036534 -0.662284                 3
# 72  -0.143663  1.695801                 2
# 107  0.137590 -0.581080                 3
# 108  0.141072 -0.587448                 3
# 126 -0.115245 -0.486251                 3
# 102  0.617677 -0.100211                 3
# 47   0.565978  0.328259                 1
# 166 -2.572560 -0.553611                 4
# 121  0.098443 -0.207686                 3
# 62   3.314355 -3.970720                 2
# 13   0.001248 -0.461341                 1
# 175 -3.332701  1.105017                 4
# 88   0.147843 -0.450835                 3
# 28   0.147558 -0.329602                 1
# 51   0.458997  0.322567                 1
# 176 -3.104220  0.600130                 4
# 170 -2.348647 -0.279385                 4
# 44   0.310121  0.056251                 1
# 125 -0.117204 -0.487035                 3
# 34  -0.016051 -0.465563                 1
# 133  0.480206  0.031182                 4
# 77   0.780280  0.155286                 3
# 45   0.428733  0.127647                 1
# 134  0.499388  0.037495                 4
# 80   0.800257  0.145018                 3
# 104  0.189466 -0.604765                 3
# 68  -0.700319 -0.820575                 2
# 154 -1.547500 -0.584803                 4
# 153 -1.032561 -0.160191                 4
# 163 -2.660456 -0.592179                 4
# 12   0.017385 -0.461360                 1
# 55   0.354020  2.990257                 2
# 1    0.646651  0.143172                 1
# 67   0.727834 -3.529465                 2
# 138  0.251857 -0.156012                 4
# 64   0.638395  0.855743                 2
# 20   0.599045  0.098145                 1
# 21   0.597959  0.137509                 1
# 59   1.473191  4.461611                 2
# 164 -2.242434 -0.354640                 4
# 128 -0.312902 -0.718490                 3
# 159 -1.322107 -0.454712                 4
# 29  -0.025079 -0.453319                 1
# 90   0.160993 -0.445603                 3
# 171  7.487139 -1.796279                 4
# 63   0.192332  3.410952                 2
# 35  -0.278013 -0.712760                 1
# 97   0.865358  0.204086                 3
# 103  0.352819 -0.311224                 3
# 117  0.576164  0.210735                 3

# %%
# Use a nearest neighbor classifier to evaluate the methods

numNeighbors_C = [1, 5, 10, 15, 20, 25, 30,35, 45,50,55,60,65,70]
trainAccC = []
testAccC = []

for k in numNeighbors_C:
    clf1 = KNeighborsClassifier(n_neighbors=k, metric='minkowski', p=2)
    clf1.fit(PCA_C_train,yLbl_C_train.values.ravel())
    PCA_C_predTrain = clf1.predict(PCA_C_train)
    PCA_C_predTest = clf1.predict(PCA_C_test)
    trainAccC.append(accuracy_score(yLbl_C_train, PCA_C_predTrain))
    testAccC.append(accuracy_score(yLbl_C_test, PCA_C_predTest))

plt.plot(numNeighbors_C, trainAccC, 'ro-', numNeighbors_C, testAccC,'bv--')
plt.legend(['Training Accuracy','Test Accuracy'])
plt.xlabel('Number of neighbors For PCA C')
plt.ylabel('Accuracy')

# Plot Confusion matrix
plot_confusion_matrix(clf1, PCA_C_test, yLbl_C_test)
plt.show()

# Calculate RMSE
MSE = mean_squared_error(yLbl_C_test, PCA_C_predTest)
 
RMSE = math.sqrt(MSE)
print("Root Mean Square Error:\n")
print(RMSE)
# Out:
# Root Mean Square Error:
#
# 0.6382847385042254
