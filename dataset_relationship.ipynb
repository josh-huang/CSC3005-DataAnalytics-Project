# %% [markdown]
# **Load csv file**

# %%
import pandas as pd # load dataset 
import seaborn as sns # generate heat map
import numpy as np
import matplotlib.pyplot as plt
tableA = pd.read_csv('5. Dataset PCA/MeterA_pca_3.csv', header='infer') # read MeterA csv file
tableA = tableA.drop('Class Attruibute', axis=1)
tableB = pd.read_csv('5. Dataset PCA/MeterB_pca_5.csv', header='infer') # read MeterB csv file
tableB = tableB.drop('Class Attruibute', axis=1)
tableC = pd.read_csv('5. Dataset PCA/MeterC_pca_6.csv', header='infer') # read MeterC csv file
tableC = tableC.drop('Class Attruibute', axis=1)

# %% [markdown]
# **Extract common features from each dataset**

# %%
tableA_extract = tableA[['PC1','PC2','PC3']][:67]
tableA_extract
# Out:
#          PC1       PC2       PC3
# 0  -0.526258  5.566278  0.389358
# 1   1.016687  3.352036  0.894510
# 2   1.058280  1.844760  0.667599
# 3  -0.173012  1.540431 -0.850760
# 4  -0.280666  1.219715 -1.401910
# ..       ...       ...       ...
# 62 -2.884711 -0.767628  1.273864
# 63 -2.831047 -0.682861  0.764677
# 64 -3.676232 -0.989616  1.137127
# 65  4.696736  1.629314  2.936891
# 66  6.036821 -0.932438  0.672652
#
# [67 rows x 3 columns]

# %%
tableB_extract = tableB[['PC1','PC2','PC3']][:67]
tableB_extract
# Out:
#          PC1       PC2       PC3
# 0   0.914365 -2.162769  0.436334
# 1   0.866350 -2.170359  0.444587
# 2   0.827614 -2.131012  0.144530
# 3   0.808412 -2.068897  0.125245
# 4   0.839467 -2.162049  0.158651
# ..       ...       ...       ...
# 62 -2.390696  0.798375 -0.436249
# 63 -2.429585  0.832941 -0.426300
# 64 -2.486759  0.867436 -0.380722
# 65 -2.578565  0.878013 -0.349289
# 66 -2.610512  0.871766 -0.295754
#
# [67 rows x 3 columns]

# %%
tableC_extract = tableC[['PC1','PC2','PC3']][:67]
tableC_extract
# Out:
#           PC1       PC2        PC3
# 0    0.321708 -0.351911  -0.364762
# 1    0.248324 -0.417809  -0.313521
# 2    0.258434 -0.426496  -0.370236
# 3    0.234022 -0.450655  -0.331455
# 4    0.282905 -0.381927  -0.374808
# ..        ...       ...        ...
# 62  -4.050253  9.304368   2.515105
# 63  10.598332  8.331448  -9.175824
# 64  14.908083  8.495496  -6.940907
# 65  11.732227  5.751882   9.855336
# 66   7.707298 -0.902089  16.936664
#
# [67 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
# define the StandardScaler
scaler = StandardScaler()\
# PCA take two principal components
pca = PCA(n_components=2)
#Scaling the data
tableA_Scaled = scaler.fit(tableA_extract).transform(tableA_extract)
tableB_Scaled = scaler.fit(tableB_extract).transform(tableB_extract)
tableC_Scaled = scaler.fit(tableC_extract).transform(tableC_extract)
tableA_Scaled
# Out:
# array([[-6.78860702e-03,  3.43425847e+00,  5.29819592e-01],
#        [ 7.47115260e-01,  1.92033883e+00,  1.14887065e+00],
#        [ 7.67438337e-01,  8.89785958e-01,  8.70797759e-01],
#        [ 1.65812074e-01,  6.81710385e-01, -9.89914246e-01],
#        [ 3.75852832e-01,  2.42236822e+00, -5.60088257e-01],
#        [ 1.76725407e-01,  1.02290931e+00,  1.06781707e+00],
#        [ 4.68597789e-01,  7.05888006e-01, -2.98772777e-01],
#        [ 7.98872374e-02,  3.87323331e-01,  1.16207179e+00],
#        [ 2.97957913e-01,  4.33490184e-01,  1.62941018e-01],
#        [ 7.78000035e-02,  4.36649810e-01,  8.91004014e-01],
#        [-8.91464036e-04,  7.58156970e-01,  3.53834737e-01],
#        [ 9.34256596e-04,  8.60401069e-01, -5.08568785e-01],
#        [-2.04862700e-01,  3.49530777e-02,  1.06464414e+00],
#        [-4.97213357e-01, -1.70538547e-01,  2.94157441e-01],
#        [-8.30761161e-01, -4.86514711e-01,  5.56603302e-01],
#        [-9.88219954e-01, -8.58593565e-01,  3.69026538e-01],
#        [-1.33425961e+00, -9.82051114e-01,  1.14407301e+00],
#        [-1.08079194e+00, -8.87636860e-01,  1.22553688e+00],
#        [-1.15916109e+00, -8.96353391e-01,  1.61375957e+00],
#        [-1.13294050e+00, -8.38397216e-01,  9.89763653e-01],
#        [-1.54590932e+00, -1.04813103e+00,  1.44619176e+00],
#        [ 2.54523759e+00,  7.42481112e-01,  3.65175778e+00],
#        [ 3.20002142e+00, -1.00903745e+00,  8.76989533e-01]])

# %%
# Calculate the covariance matrix
tableA_covarianceMatrix = np.cov(np.transpose(np.array(tableA_Scaled)))
tableB_covarianceMatrix = np.cov(np.transpose(np.array(tableB_Scaled)))
tableC_covarianceMatrix = np.cov(np.transpose(np.array(tableC_Scaled)))
# Calculate the principal components in the data
pca_tableA = pca.fit(tableA_covarianceMatrix).transform(tableA_covarianceMatrix)
pca_tableB = pca.fit(tableB_covarianceMatrix).transform(tableB_covarianceMatrix)
pca_tableC = pca.fit(tableC_covarianceMatrix).transform(tableC_covarianceMatrix)

# %%
# vertically add the two principal component to make a single vector
df_pca_tableA = pd.DataFrame(pca_tableA, columns=['PC1','PC2'])
df_pca_tableB = pd.DataFrame(pca_tableB, columns=['PC1','PC2'])
df_pca_tableC = pd.DataFrame(pca_tableC, columns=['PC1','PC2'])

tableA_pca_vertically = df_pca_tableA['PC1'].append(df_pca_tableA['PC2']).reset_index(drop=True)
tableB_pca_vertically = df_pca_tableB['PC1'].append(df_pca_tableB['PC2']).reset_index(drop=True)
tableC_pca_vertically = df_pca_tableC['PC1'].append(df_pca_tableC['PC2']).reset_index(drop=True)

# print out the correlation between three datasets
print('correlation of data of tableA and tableB is {}'.format(np.corrcoef(tableA_pca_vertically,tableB_pca_vertically)[0,1]))
print('correlation of data of tableB and tableC is {}'.format(np.corrcoef(tableB_pca_vertically,tableC_pca_vertically)[0,1]))
print('correlation of data of tableA and tableC is {}'.format(np.corrcoef(tableA_pca_vertically,tableC_pca_vertically)[0,1]))
# Out:
# correlation of data of tableA and tableB is 0.928182280936152
# correlation of data of tableB and tableC is 0.03970312261132252
# correlation of data of tableA and tableC is 0.3181649901587743

# %% [markdown]
# **Since the correlation between each datasets are all below 0 which indicates a negative relation**
