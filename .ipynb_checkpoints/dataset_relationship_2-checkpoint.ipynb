# %%
import pandas as pd # load dataset 
import seaborn as sns # generate heat map
import numpy as np
import matplotlib.pyplot as plt
tableA = pd.read_csv('4. Dataset Aggregation File/MeterA_aggregation.csv', header='infer') # read MeterA csv file
tableA = tableA.drop('Class Attruibute', axis=1)
tableB = pd.read_csv('4. Dataset Aggregation File/MeterB_aggregation.csv', header='infer') # read MeterB csv file
tableB = tableB.drop('Class Attruibute', axis=1)
tableC = pd.read_csv('4. Dataset Aggregation File/MeterC_aggregation.csv', header='infer') # read MeterC csv file
tableC = tableC.drop('Class Attruibute', axis=1)

# %%
tableA_extract = tableA[["Average Flow Velocity","Average speed of sound","Average Gain"]][:67]
tableA_extract
# Out:
#     Average Flow Velocity  Average speed of sound  Average Gain
# 0                9.350917             1485.391229     35.064189
# 1                8.323063             1485.919896     34.975281
# 2                7.273721             1485.903146     34.920553
# 3                6.214215             1484.790938     34.878133
# 4                6.209143             1484.252875     34.882507
# ..                    ...                     ...           ...
# 62               3.125155             1484.576833     34.780579
# 63               3.122619             1484.555313     34.780375
# 64               2.089232             1484.511438     34.760538
# 65               9.145977             1487.266104     34.960632
# 66               7.169202             1486.742083     34.842021
#
# [67 rows x 3 columns]

# %%
tableB_extract = tableB[["Average flow velocity","Average speed of sound","Average Gain"]][:67]
tableB_extract
# Out:
#     Average flow velocity  Average speed of sound  Average Gain
# 0                2.394439             1485.153222     51.475000
# 1                2.396089             1485.030722     51.475000
# 2                3.523517             1485.061111     51.475000
# 3                3.525933             1485.131278     51.475000
# 4                3.525128             1485.103278     51.475000
# ..                    ...                     ...           ...
# 62               6.183078             1505.658889     63.567222
# 63               6.193783             1505.746167     63.550000
# 64               6.189289             1505.570500     63.550000
# 65               6.199967             1505.559500     63.550000
# 66               6.202361             1505.734444     63.550000
#
# [67 rows x 3 columns]

# %%
tableC_extract = tableC[["Average Flow Velocity","Average Speed of Sound","Average Gain"]][:67]
tableC_extract
# Out:
#     Average Flow Velocity  Average Speed of Sound  Average Gain
# 0               15.917361             1485.476389     15.109722
# 1               14.729722             1485.268750     15.100000
# 2               14.743750             1485.106250     15.100000
# 3               14.724167             1485.181250     15.100000
# 4               14.705417             1485.238889     15.100000
# ..                    ...                     ...           ...
# 62              14.606458             1485.570139     14.950000
# 63              14.601944             1485.827778     14.950000
# 64              14.619375             1485.677778     14.950000
# 65              13.339236             1485.514583     14.950000
# 66              12.251111             1485.568750     14.950000
#
# [67 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
scaler = StandardScaler()
pca = PCA(n_components=2)
tableA_Scaled = scaler.fit(tableA_extract).transform(tableA_extract)
tableB_Scaled = scaler.fit(tableB_extract).transform(tableB_extract)
tableC_Scaled = scaler.fit(tableC_extract).transform(tableC_extract)
tableA_Scaled
# Out:
# array([[ 2.18530131e+00,  7.76634303e-01,  3.21316514e+00],
#        [ 1.65235322e+00,  1.52926718e+00,  1.93183864e+00],
#        [ 1.10826323e+00,  1.50542117e+00,  1.14311074e+00],
#        [ 5.58903233e-01, -7.79655549e-02,  5.31777587e-01],
#        [-1.05736408e+00, -6.57062091e-01, -1.12190421e+00],
#        [ 1.58283788e+00,  4.97630244e-01,  2.10336514e+00],
#        [ 1.09019366e+00,  2.78123058e-01,  1.25600105e+00],
#        [ 5.57921172e-01,  3.13180258e-01,  5.09783213e-01],
#        [ 5.59601898e-01,  2.06613489e-01,  4.68733825e-01],
#        [ 5.54003547e-01,  9.61032294e-02,  4.96584455e-01],
#        [ 5.61142833e-01,  8.84674903e-03,  4.96590472e-01],
#        [ 5.56490301e-01, -5.46833033e-02,  5.46428001e-01],
#        [ 5.56075626e-01, -4.76248831e-02,  5.78690762e-01],
#        [ 5.18616131e-02, -7.32803470e-02, -4.14380516e-02],
#        [-4.96650526e-01, -1.01485555e-01, -5.56025039e-01],
#        [-1.04024737e+00, -1.78125932e-01, -8.99075009e-01],
#        [-1.04037773e+00, -2.56692498e-01, -9.26924171e-01],
#        [-1.04162871e+00, -3.36060574e-01, -9.02003894e-01],
#        [-1.04105654e+00, -3.58216725e-01, -8.80015518e-01],
#        [-1.04279271e+00, -3.82774560e-01, -8.74144219e-01],
#        [-1.04410762e+00, -4.13411349e-01, -8.77085129e-01],
#        [-1.57992481e+00, -4.75873670e-01, -1.16296862e+00],
#        [ 2.07903869e+00,  3.44578628e+00,  1.72072796e+00],
#        [ 1.05406925e+00,  2.69976764e+00,  1.13418551e-02]])

# %%
tableA_covarianceMatrix = np.cov(np.transpose(np.array(tableA_Scaled)))
tableB_covarianceMatrix = np.cov(np.transpose(np.array(tableB_Scaled)))
tableC_covarianceMatrix = np.cov(np.transpose(np.array(tableC_Scaled)))

pca_tableA = pca.fit(tableA_covarianceMatrix).transform(tableA_covarianceMatrix)
pca_tableB = pca.fit(tableB_covarianceMatrix).transform(tableB_covarianceMatrix)
pca_tableC = pca.fit(tableC_covarianceMatrix).transform(tableC_covarianceMatrix)

# %%
df_pca_tableA = pd.DataFrame(pca_tableA, columns=['PC1','PC2'])
df_pca_tableB = pd.DataFrame(pca_tableB, columns=['PC1','PC2'])
df_pca_tableC = pd.DataFrame(pca_tableC, columns=['PC1','PC2'])

tableA_pca_vertically = df_pca_tableA['PC1'].append(df_pca_tableA['PC2']).reset_index(drop=True)
tableB_pca_vertically = df_pca_tableB['PC1'].append(df_pca_tableB['PC2']).reset_index(drop=True)
tableC_pca_vertically = df_pca_tableC['PC1'].append(df_pca_tableC['PC2']).reset_index(drop=True)
print('correlation of data of tableA and tableB is {}'.format(np.corrcoef(tableA_pca_vertically,tableB_pca_vertically)[0,1]))
print('correlation of data of tableB and tableC is {}'.format(np.corrcoef(tableB_pca_vertically,tableC_pca_vertically)[0,1]))
print('correlation of data of tableA and tableC is {}'.format(np.corrcoef(tableA_pca_vertically,tableC_pca_vertically)[0,1]))
# Out:
#   File "<ipython-input-7-9ca39bf10398>", line 5
#     tableA_pca_vertically = df_pca_tableA['PC1'].append([df_pca_tableA['PC2']).reset_index(drop=True)
#                                                                              ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['
