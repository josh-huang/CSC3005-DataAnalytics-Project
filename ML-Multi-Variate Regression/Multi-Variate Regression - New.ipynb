# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score
from sklearn import metrics

# %%
#extracting features and labels from datasets

dataframeA = pd.read_csv('../5. Dataset PCA/MeterA_pca_3.csv')
dataframeA = dataframeA.drop('Unnamed: 0', axis=1)
dataframeA_feature = dataframeA.drop('Class Attruibute', axis=1)
dataframeA_label = dataframeA['Class Attruibute']

dataframeB = pd.read_csv('../5. Dataset PCA/MeterB_pca_5.csv')
dataframeB = dataframeB.drop('Unnamed: 0', axis=1)
dataframeB_feature = dataframeB.drop('Class Attruibute', axis=1)
dataframeB_label = dataframeB['Class Attruibute']

dataframeC = pd.read_csv('../5. Dataset PCA/MeterC_pca_6.csv')
dataframeC = dataframeC.drop('Unnamed: 0', axis=1)
dataframeC_feature = dataframeC.drop('Class Attruibute', axis=1)
dataframeC_label = dataframeC['Class Attruibute']

# %% [markdown]
# Multi-Variate Regression - Dataset A

# %%
X = dataframeA_feature # Features
y = dataframeA_label # Target variable

# split X and y into training and testing sets
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# define the multinomial logistic regression model
model = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=500)
# fit the model on the whole dataset
model.fit(X_train, y_train)

# predict the class label
y_pred=model.predict(X_test)

# Measure accuracy
score_train = np.round(accuracy_score(y_train, model.predict(X_train)), 2)
score_test = np.round(accuracy_score(y_test, y_pred), 2)
print("Train accuracy for feature selection A :", score_train)
print("Test accuracy for feature selection A :", score_test)

# Creating  a confusion matrix,which compares the y_test and y_pred
from sklearn.metrics import mean_squared_error
rmse = mean_squared_error(y_test, y_pred)
print("Root Means Square Error for feature selection A :",rmse)

# Creating  a confusion matrix,which compares the y_test and y_pred
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

#plotting confusion matrix
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score_train)
plt.title(all_sample_title, size = 15);
# Out:
# Train accuracy for feature selection A : 0.83
# Test accuracy for feature selection A : 0.71
# Root Means Square Error for feature selection A : 0.29411764705882354

# %% [markdown]
# Multi-Variate Regression - Dataset B

# %%
X = dataframeB_feature # Features
y = dataframeB_label # Target variable

# split X and y into training and testing sets
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# define the multinomial logistic regression model
model = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=500)
# fit the model on the whole dataset
model.fit(X_train, y_train)

# predict the class label
y_pred=model.predict(X_test)

# Measure accuracy
score_train = np.round(accuracy_score(y_train, model.predict(X_train)), 2)
score_test = np.round(accuracy_score(y_test, y_pred), 2)
print("Train accuracy for feature selection B :", score_train)
print("Test accuracy for feature selection B :", score_test)

# Creating  a confusion matrix,which compares the y_test and y_pred
from sklearn.metrics import mean_squared_error
rmse = mean_squared_error(y_test, y_pred)
print("Root Means Square Error for feature selection B :",rmse)

# Creating  a confusion matrix,which compares the y_test and y_pred
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

#plotting confusion matrix
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score_train)
plt.title(all_sample_title, size = 15);
# Out:
# Train accuracy for feature selection B : 1.0
# Test accuracy for feature selection B : 0.93
# Root Means Square Error for feature selection B : 0.07142857142857142

# %% [markdown]
# Multi-Variate Regression - Dataset C

# %%
X = dataframeC_feature # Features
y = dataframeC_label # Target variable

# split X and y into training and testing sets
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# define the multinomial logistic regression model
model = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=500)
# fit the model on the whole dataset
model.fit(X_train, y_train)

# predict the class label
y_pred=model.predict(X_test)

# Measure accuracy
score_train = np.round(accuracy_score(y_train, model.predict(X_train)), 2)
score_test = np.round(accuracy_score(y_test, y_pred), 2)
print("Train accuracy for feature selection C :", score_train)
print("Test accuracy for feature selection C :", score_test)

# Creating  a confusion matrix,which compares the y_test and y_pred
from sklearn.metrics import mean_squared_error
rmse = mean_squared_error(y_test, y_pred)
print("Root Means Square Error for feature selection C :",rmse)

# Creating  a confusion matrix,which compares the y_test and y_pred
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

#plotting confusion matrix
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score_train)
plt.title(all_sample_title, size = 15);
# Out:
# Train accuracy for feature selection C : 0.76
# Test accuracy for feature selection C : 0.71
# Root Means Square Error for feature selection C : 1.096774193548387
